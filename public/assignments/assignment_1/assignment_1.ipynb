# %% [markdown]
# ## Training Goal
# Prefix Expansion
#
# ## Steps Shown
# ### 1. Data Cleaning (read_vocabulary 6-8)
# Loading text, lowercasing, removing punctuation
#
# ### 1a. tokenization (read_vocabulary 9)
# Splitting into array
#
# ### 2. model training (read_vocabulary 10-12)
# Computing word frequencies via Counter and sorting by frequency (this IS your model - a frequency-based language model)
#
# ### 3. inference (autocomplete_word)
# - Inference doesn't require neural networks; it just means using your model to make predictions
# - Your "model" (frequency-sorted vocab) predicts the most likely completions by returning frequent words first

# %%
with open("shakespeare-edit.txt", "r") as f:
    for i in range(5):
        print(f.readline())
# Out:
#                      1
#
#   From fairest creatures we desire increase,
#
#   That thereby beauty's rose might never die,
#
#   But as the riper should by time decease,
#
#   His tender heir might bear his memory:

# %%
import re
from collections import Counter

def read_vocabulary(filename):
    with open(filename, "r") as f:
        text = f.read().lower()
    # Remove punctuation/digits
    text = re.sub(r"[^a-z\s]", "", text)
    words = text.split()
    counter = Counter(words)
    # Sort by frequency (most common first)
    vocab = [word for word, _ in counter.most_common()]
    return vocab

print(read_vocabulary("tiny.txt"))
print(read_vocabulary("shakespeare-edit.txt"))
# Out:
# ['hello', 'world']
# ['the', 'and', 'i', 'to', 'of', 'a', 'you', 'my', 'in', 'that', 'is', 'not', 'me', 'with', 'it', 'for', 'be', 'his', 'your', 'this', 'but', 'he', 'have', 'as', 'thou', 'him', 'so', 'will', 'what', 'thy', 'all', 'her', 'no', 'do', 'by', 'shall', 'if', 'are', 'we', 'thee', 'lord', 'our', 'on', 'king', 'good', 'now', 'sir', 'from', 'o', 'at', 'come', 'they', 'well', 'or', 'which', 'would', 'more', 'was', 'then', 'she', 'am', 'how', 'here', 'let', 'enter', 'their', 'love', 'when', 'ill', 'them', 'hath', 'than', 'man', 'an', 'there', 'one', 'upon', 'go', 'like', 'say', 'know', 'may', 'make', 'did', 'us', 'should', 'were', 'yet', 'must', 'why', 'see', 'had', 'tis', 'such', 'out', 'some', 'give', 'these', 'where', 'too', 'can', 'who', 'take', 'most', 'speak', 'mine', 'first', 'th', 'duke', 'up', 'tell', 'time', 'much', 'exeunt', 'think', 'never', 'heart', 'exit', 'nor', 'queen', 'doth', 'art', 'great', 'lady', 'hear', 'death', 'away', 'men', 'father', 'hand', 'life', 'look', 'before', 'made', 'very', 'sweet', 'scene', 'true', 'thus', 'god', 'own', 'again', 'master', 'ay', 'fair', 'cannot', 'prince', 'pray', 'day', 'old', 'any', 'two', 'been', 'eyes', 'son', 'other', 'being', 'down', 'leave', 'done', 'name', 'blood', 'into', 'both', 'night', 'nothing', 'therefore', 'poor', 'though', 'fear', 'till', 'world', 'could', 'heaven', 'comes', 'whose', 'noble', 'better', 'ever', 'against', 'hast', 'grace', 'nay', 'gloucester', 'honour', 'many', 'myself', 'henry', 'stand', 'even', 'way', 'brother', 'call', 'still', 'second', 'john', 'those', 'bear', 'dead', 'house', 'france', 'peace', 'find', 'caesar', 'head', 'gentleman', 'live', 'antony', 'madam', 'wife', 'part', 'richard', 'lords', 'might', 'put', 'word', 'every', 'within', 'york', 'little', 'off', 'keep', 'die', 'friends', 'none', 'aside', 'brutus', 'young', 'hold', 'gone', 'fool', 'set', 'best', 'thine', 'long', 'mistress', 'himself', 'dear', 'falstaff', 'bring', 'since', 'soul', 'indeed', 'friend', 'dost', 'page', 'another', 'place', 'unto', 'stay', 'words', 'whom', 'boy', 'eye', 'once', 'show', 'face', 'full', 'else', 'warwick', 'daughter', 'gods', 'after', 'faith', 'thats', 'tongue', 'about', 'theres', 'please', 'three', 'answer', 'has', 'said', 'thought', 'gentle', 'hence', 'forth', 'marry', 'without', 'welcome', 'servant', 'iago', 'ham', 'mind', 'ere', 'makes', 'mother', 'matter', 'hope', 'thing', 'clown', 'right', 'farewell', 'act', 'sword', 'rest', 'end', 'heard', 'nature', 'back', 'bid', 'cause', 'came', 'things', 'whats', 'truth', 'home', 'othello', 'use', 'meet', 'lie', 'woman', 'thousand', 'rather', 'edward', 'hands', 'does', 'help', 'fortune', 'enough', 'only', 'timon', 'fellow', 'follow', 'wilt', 'play', 'state', 'power', 'news', 'fall', 'earth', 'shame', 'get', 'pardon', 'hour', 'rome', 'hes', 'shalt', 'messenger', 'hither', 'sure', 'false', 'ye', 'thank', 'husband', 'under', 'loves', 'honest', 'kings', 'macbeth', 'tears', 'mean', 'reason', 'yourself', 'youth', 'lay', 'fight', 'fathers', 'far', 'ford', 'kind', 'hell', 'bed', 'lets', 'last', 'turn', 'sent', 'england', 'light', 'near', 'rosalind', 'means', 'seen', 'cleopatra', 'spirit', 'lucius', 'through', 'wit', 'saw', 'cousin', 'crown', 'majesty', 'body', 'send', 'sleep', 'lost', 'swear', 'court', 'yours', 'hot', 'break', 'buckingham', 'together', 'fire', 'shallow', 'antonio', 'soldier', 'troilus', 'arms', 'prove', 'reenter', 'suffolk', 'war', 'thoughts', 'strange', 'letter', 'left', 'while', 'cassio', 'lies', 'present', 'villain', 'fly', 'speed', 'mad', 'says', 'itself', 'syracuse', 'justice', 'alone', 'each', 'times', 'between', 'child', 'believe', 'beat', 'high', 'tomorrow', 'business', 'titus', 'valentine', 'cassius', 'lear', 'days', 'others', 'gave', 'wrong', 'seek', 'mark', 'told', 'desdemona', 'bloody', 'hearts', 'alas', 'french', 'found', 'soldiers', 'dromio', 'sun', 'horse', 'beseech', 'antipholus', 'proteus', 'desire', 'foul', 'less', 'gold', 'worthy', 'third', 'sound', 'devil', 'service', 'ha', 'same', 'neer', 'mr ...

# %%
def process_data(vocab):
    return vocab

def autocomplete_word(prefix, vocab):
    results = [word for word in vocab if word.startswith(prefix)]
    return results[:10]  # top 10

# %%
vocab = read_vocabulary("shakespeare-edit.txt")
print(autocomplete_word("love", vocab))
print(autocomplete_word("the", vocab))
print(autocomplete_word("thou", vocab))
print(autocomplete_word("rome", vocab))
# Out:
# ['love', 'loves', 'lovers', 'lovely', 'lover', 'loved', 'lovell', 'lovel', 'lovest', 'lovesong']
# ['the', 'thee', 'they', 'then', 'their', 'them', 'there', 'these', 'therefore', 'theres']
# ['thou', 'though', 'thought', 'thousand', 'thoughts', 'thourt', 'thousands', 'thoult', 'thoudst', 'thout']
# ['rome', 'romeo', 'romes', 'romeos', 'romei']

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Assume you already defined: autocomplete_word(prefix, model)

# Create a text box
textbox = widgets.Text(
    placeholder="Type a word prefix...",
    description="Prefix:",
    disabled=False
)

# Create an output display area
output = widgets.Output()

# Define what happens when textbox changes
def on_value_change(change):
    prefix = change['new']
    suggestions = autocomplete_word(prefix, vocab)  # <- your function + data structure
    with output:
        clear_output()
        if suggestions:
            print("Suggestions:")
            for word in suggestions:
                print(word)
        else:
            print("No suggestions found.")

# Hook the function up to the textbox
textbox.observe(on_value_change, names='value')

# Display UI
display(textbox, output)
# Out:
# Text(value='', description='Prefix:', placeholder='Type a word prefix...')
# Output()

# %% [markdown]
# <!-- Convert to .py
# jupyter nbconvert --to script my_notebook.ipynb
#  -->
